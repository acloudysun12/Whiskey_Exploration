# %%
import numpy as np
import pandas as pd
import csv
from scipy import stats
import os
import datetime
import statsmodels.api as sm
import requests
import sys, json
import time
import random
import json
import re

# %%
# DATA PREP. READ IN FILE

df_whisk_main_char = pd.read_csv('../Datasets/single_malt_main.csv', index_col = False)
df_peated_main_char = pd.read_csv('../Datasets/single_malt_peated_main.csv', index_col = False)
df_main_char = pd.concat([df_whisk_main_char, df_peated_main_char]).reset_index(drop = True)

df_whisk_profiles = pd.read_csv('../Datasets/single_malt_profiles.csv', index_col = False)
df_whisk_profiles['Brand'] = df_whisk_profiles['Brand'].str.upper()
df_peated_profiles = pd.read_csv('../Datasets/single_malt_peated_profiles.csv', index_col = False)
df_peated_profiles['Brand'] = df_peated_profiles['Brand'].str.upper()
df_profiles = pd.concat([df_whisk_profiles, df_peated_profiles]).reset_index(drop = True)

df_whisk_distillers = pd.read_csv('../Datasets/distilleries.csv', engine = 'python', index_col = False)
df_whisk_distillers['Distillery'] = df_whisk_distillers['Distillery'].str.upper()

# %%
# JOIN AND INITIAL CLEAN 

df_main_full = pd.merge(df_main_char, df_profiles, on = ["Whisk_Name", "URL"], how="left")

for idx in range(len(df_main_full)):
    raw_text = df_main_full['Whisk_Name'].loc[idx]
    raw_text = re.sub(u"[Á]", 'A', raw_text)
    raw_text = re.sub(u"[É]", 'E', raw_text)
    raw_text = re.sub(u"[Í]", 'I', raw_text)
    raw_text = re.sub(u"[Ó]", 'O', raw_text)
    raw_text = re.sub(u"[ÚÜ]", 'U', raw_text)
    df_main_full['Whisk_Name'].loc[idx] = raw_text
# Out:
# C:\Users\aclou\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_main_full.loc[(1, 1401),]
# Out:
#                  Whisk_Name          Whisk_Type            Whisk_Loc  \
# 1     GLENGLASSAUGH 30 YEAR         Single Malt  Highlands, Scotland
# 1401      LAPHROAIG 10 YEAR  Peated Single Malt      Islay, Scotland
#
#       Communal_Rating  Distiller_Score  \
# 1                4.38              NaN
# 1401             3.98             96.0
#
#                                                     URL  Num_Revs  \
# 1     https://distiller.com/spirits/glenglassaugh-30...         9
# 1401         https://distiller.com/spirits/laphroaig-10      8777
#
#               Brand                Cost      Age   ABV           Flavor  \
# 1     GLENGLASSAUGH  spirit-cost cost-5  30 YEAR  42.0              NaN
# 1401      LAPHROAIG  spirit-cost cost-3  10 YEAR  43.0  PEATY & VANILLA
#
#                                                 Profile
# 1                                                   NaN
# 1401  {"smoky":70,"peaty":90,"spicy":50,"herbal":20,...

# %%
# BREAK OUT PROFILES INTO COLUMNS

if np.isnan(df_main_char['Distiller_Score'][0]):
    ls_of_ls = [float("nan")]*14
    ls_of_ls = [ls_of_ls]
else: 
    ls_of_ls = list(json.loads(df_profiles['Profile'][0]).values())
    ls_of_ls = [ls_of_ls]

for idx in range(1, len(df_main_char)): 
    if np.isnan(df_main_char['Distiller_Score'][idx]):
        list_append = [float("nan")]*14
    else: 
        list_append = list(json.loads(df_profiles['Profile'][idx]).values())
    ls_of_ls.append(list_append)

profiles_full = pd.DataFrame(ls_of_ls, columns = list(json.loads(df_profiles['Profile'][0]).keys())) # we know the first one has the keys

# %%
df_main_full = pd.concat([df_main_full.reset_index(drop = True), profiles_full], axis = 1)
df_main_full.head(3)
# Out:
#                                Whisk_Name   Whisk_Type            Whisk_Loc  \
# 0  TULLIBARDINE THE MURRAY MARSALA FINISH  Single Malt  Highlands, Scotland
# 1                   GLENGLASSAUGH 30 YEAR  Single Malt  Highlands, Scotland
# 2       LEDAIG 13 AMONTILLADO CASK FINISH  Single Malt    Islands, Scotland
#
#    Communal_Rating  Distiller_Score  \
# 0             4.19             86.0
# 1             4.38              NaN
# 2             3.84              NaN
#
#                                                  URL  Num_Revs          Brand  \
# 0  https://distiller.com/spirits/tullibardine-the...         8   TULLIBARDINE
# 1  https://distiller.com/spirits/glenglassaugh-30...         9  GLENGLASSAUGH
# 2  https://distiller.com/spirits/ledaig-13-amonti...         9            NaN
#
#                  Cost      Age  ...  oily full_bodied  rich  sweet  briny  \
# 0  spirit-cost cost-3      NAS  ...  40.0        35.0  40.0   45.0    0.0
# 1  spirit-cost cost-5  30 YEAR  ...   NaN         NaN   NaN    NaN    NaN
# 2  spirit-cost cost-4       13  ...   NaN         NaN   NaN    NaN    NaN
#
#    salty  vanilla  tart  fruity  floral
# 0    0.0     20.0  20.0    35.0    10.0
# 1    NaN      NaN   NaN     NaN     NaN
# 2    NaN      NaN   NaN     NaN     NaN
#
# [3 rows x 27 columns]

# %%
# CLEAN UP AGE + COST

age_final = [re.sub(r'YEAR(.*)','', str(x)) for x in df_main_full['Age']]
age_final = [re.sub(r'NAS(.*)','NAS', str(y)) for y in age_final]
age_final = [re.sub(r'nan','NAS', str(y)) for y in age_final]
age_final = [str(y).strip() for y in age_final]
df_main_full['Age'] = age_final

cost_final = [re.sub(r'spirit-cost cost-','', str(x)) for x in df_main_full['Cost']]
cost_final = [re.sub(r'NAS(.*)','NAS', str(y)) for y in cost_final]
cost_final = [re.sub(r'nan','NAS', str(y)) for y in cost_final]
cost_final = [str(y).strip() for y in cost_final]
df_main_full['Cost'] = cost_final

# %%
# CLEAN UP DISTILLERS
distiller = []
for idx in range(len(df_main_full)):
    distiller_name = [distiller for distiller in df_whisk_distillers['Distillery'] if distiller in df_main_full['Whisk_Name'][idx]]
    if len(distiller_name) == 0:
        distiller.append("MISSING")
    else:
        distiller.append(distiller_name[0])

df_main_full['Distiller'] = distiller
df_main_full['Distiller'] = np.where(df_main_full['Distiller'] == "MISSING", \
                                     df_main_full['Brand'], df_main_full['Distiller'])

# %%
df_main_full[df_main_full['Distiller'].isnull()] # MISSING DISTILLERS
# Out:
#                                              Whisk_Name          Whisk_Type  \
# 2                     LEDAIG 13 AMONTILLADO CASK FINISH         Single Malt
# 29    SHIELDAIG SINGLE MALT SCOTCH WHISKY OLOROSO CA...         Single Malt
# 30                         GLEN FOHDRY DARAICH IAPANACH         Single Malt
# 31                                  SILVER SEAL 12 YEAR         Single Malt
# 32                                      ISLAY GOLD ORLA         Single Malt
# 36                                  CU BOCAN CREATION 1         Single Malt
# 46                                         KIRKWALL BAY         Single Malt
# 58                  GELFLING WING SEALANT (36.160 SMWS)         Single Malt
# 75                                      LISMORE 18 YEAR         Single Malt
# 79                       THE HALF CENTURY BLEND BATCH 3         Single Malt
# 90                        LEDAIG 19 YEAR MASARLA FINISH         Single Malt
# 100                              HIGHLAND QUEEN MAJESTY         Single Malt
# 103                                            ANCOC 12         Single Malt
# 160                    KILKERRAN 8 CASK STRENGTH (2021)         Single Malt
# 168                    GLENGOYONE CASK STRENGTH BATCH 5         Single Malt
# 169     GRANGESTONE 25YR SINGLE MALT SHERRY CASK FINISH         Single Malt
# 170                                  GLEN MARNOCH ISLAY         Single Malt
# 176   LEDAIG 2005 HERMITAGE WOOD FINISH (GORDON & MA...         Single Malt
# 194        SEAWEED & AEONS & DIGGING & FIRE 10 YEAR OLD         Single Malt
# 201                                       KING'S FALCON         Single Malt
# 205                                PIITYVAICH 12 YR OLD         Single Malt
# 222              THAT BOUTIQUE-Y WHISKY COMPANY INCHFAD         Single Malt
# 224                      SPEY RIVER BOURBON CASK FINISH         Single Malt
# 231                           SMOKEHEAD ROCK EDITION II         Single Malt
# 238                SHIELDAIG 21 YEAR SINGLE MALT WHISKY         Single Malt
# 247   TRADER JOE’S HIGHLAND SINGLE MALT SCOTCH WHISK...         Single Malt
# 264                       SPEY RIVER SHERRY CASK FINISH         Single Malt
# 265                           GLEN FOHDRY FION FRANGACH         Single Malt
# 266                                         GRANGESTONE         Single Malt
# 268                                         DUN BHEAGAN         Single Malt
# 368                           PORT CHARLOTTE MC:01 2009         Single Malt
# 390                     LONGROW RED 13 CHILEAN CAB SAUV         Single Malt
# 391                                  CRABBIE’S YARDHEAD         Single Malt
# 400   TRADER JOE’S HIGHLAND SINGLE MALT SCOTCH WHISK...         Single Malt
# 416                                         GLEN FOHDRY         Single Malt
# 428             ISLAY GOLD SINGLE MALT SCOTCH WHISKY 10         Single Malt
# 432                                           BALNELLAN         Single Malt
# 474                                          SPEY TENNE         Single Malt
# 485                     LONGROW 13 YEAR RED MALBEC CASK         Single Malt
# 491                    BEN BRACKEN HIGHLAND SINGLE MALT         Single Malt
# 492                    GLEN TURNER HERITAGE DOUBLE CASK         Single Malt
# 506        KILKERRAN 8 CASK STRENGTH (SHERRY CASK 2019)         Single Malt
# 518   KIRKLAND 18 YEAR HIGHLAND SINGLE MALT SHERRY C...         Single Malt
# 533                       BEN BRACKEN ISLAY SINGLE MALT         Single Malt
# 542                                           GLEN NESS         Single Malt
# 1000                  LEDAIG SINCLAIR SERIES RIOJA CASK  Peated Single Malt
# 1002  'AS WE GET IT' CASK STRENGTH ISLAY SINGLE MALT...  Peated Single Malt
# 1005                               SMOKEHEAD EXTRA RARE  Peated Single Malt
# 1017              A.D RATTRAY CASK ISLAY SHERRY EDITION  Peated Single Malt
# 1033             GLENGARRY SINGLE MALT PEATED AND SMOKY  Peated Single Malt
# 1049                              ANCNOC PEATED EDITION  Peated Single Malt
# 1104                  KIRKLAND ISLAY SINGLE MALT SCOTCH  Peated Single Malt
# 1183  PORT CHARLOTTE HEAVILY PEATED ISLAY SINGLE MAL...  Peated Single Malt
# 1190                     LEDAIG 1996 SHERRY CASK FINISH  Peated Single Malt
# 1234                        MACLEOD'S ISLAY SINGLE MALT  Peated Single Malt
# 1315               CREAG ISLE SINGLE MALT SCOTCH WHISKY  Peated Single Malt
#
#                          Whisk_Loc  Communal_Rating  Distiller_Score  \
# 2                Islands, Scotland             3.84              NaN
# 29              Speyside, Scotland             3.25              NaN
# 30              Speyside, Scotland             3.43              NaN
# 31              Speyside, Scotland             3.75              NaN
# 32                 Islay, Scotland             2.82              NaN
# 36              Highland, Scotland             3.43              NaN
# 46          Orkney Isles, Scotland             3.43              NaN
# 58              Speyside, Scotland             3.96              NaN
# 75              Speyside, Scotland             3.42              NaN
# 79                        Scotland             4.54              NaN
# 90                Island, Scotland             4.50              NaN
# 100             Highland, Scotland             2.79              NaN
# 103             Highland, Scotland             3.04              NaN
# 160         Campbeltown , Scotland             4.00              NaN
# 168             Highland, Scotland             3.61              NaN
# 169             Highland, Scotland             4.25              NaN
# 170                Islay, Scotland             3.13              NaN
# 176               Island, Scotland             4.05              NaN
# 194                Islay, Scotland             4.06              NaN
# 201             Speyside, Scotland             2.85              NaN
# 205            Speyside , Scotland             3.61              NaN
# 222                       Scotland             3.06              NaN
# 224             Speyside, Scotland             3.00              NaN
# 231                Islay, Scotland             2.84              NaN
# 238             Speyside, Scotland             4.16              NaN
# 247             Highland, Scotland             3.31              NaN
# 264                       Scotland             3.33              NaN
# 265            Spreyside, Scotland             2.63              NaN
# 266            Highland , Scotland             2.86              NaN
# 268                Islay, Scotland             3.44              NaN
# 368                Islay, Scotland             4.21              NaN
# 390          Cambeltown , Scotland             4.17              NaN
# 391             Highland, Scotland             2.65              NaN
# 400             Highland, Scotland             2.42              NaN
# 416             Dublaich, Scotland             3.25              NaN
# 428                Islay, Scotland             3.89              NaN
# 432   Speyside Glenlivet, Scotland             3.72              NaN
# 474             Speyside, Scotland             3.46              NaN
# 485         Campbeltown , Scotland             4.22              NaN
# 491             Highland, Scotland             3.11              NaN
# 492            Highlands, Scotland             3.09              NaN
# 506          Campbeltown, Scotland             4.19              NaN
# 518            Highlands, Scotland             3.88              NaN
# 533                Islay, Scotland             3.24              NaN
# 542             Highlanf, Scotland             2.75              NaN
# 1000        Isle of mull, Scotland             3.36              NaN
# 1002               Islay, Scotland             3.64              NaN
# 1005               Islay, Scotland             3.56              NaN
# 1017               Islay, Scotland             3.72              NaN
# 1033            Highland, Scotland             2.70              NaN
# 1049            Hignland, Scotland             3.54              NaN
# 1104                      Scotland             3.64              NaN
# 1183               Islay, Scotland             3.92              NaN
# 1190              Island, Scotland             4.10              NaN
# 1234                      Scotland             3.19              NaN
# 1315               Islay, Scotland             3.24              NaN
#
#                                                     URL  Num_Revs Brand Cost  \
# 2     https://distiller.com/spirits/ledaig-13-amonti...         9   NaN    4
# 29    https://distiller.com/spirits/shieldaig-single...         9   NaN    2
# 30    https://distiller.com/spirits/glen-fohdry-dara...         7   NaN    3
# 31    https://distiller.com/spirits/silver-seal-12-year         7   NaN    1
# 32        https://distiller.com/spirits/islay-gold-orla         7   NaN    2
# 36    https://distiller.com/spirits/cu-bocan-creation-1         7   NaN    3
# 46           https://distiller.com/spirits/kirkwall-bay         8   NaN    3
# 58    https://distiller.com/spirits/gelfling-wing-se...         6   NaN    4
# 75        https://distiller.com/spirits/lismore-18-year         6   NaN    2
# 79    https://distiller.com/spirits/the-half-century...         6   NaN    5
# 90    https://distiller.com/spirits/ledaig-19-year-m...         7   NaN    4
# 100   https://distiller.com/spirits/highland-queen-m...         7   NaN    2
# 103              https://distiller.com/spirits/ancoc-12         7   NaN    2
# 160   https://distiller.com/spirits/kilkerran-8-cask...        10   NaN    3
# 168   https://distiller.com/spirits/glengoyone-cask-...        11   NaN    4
# 169   https://distiller.com/spirits/grangestone-25yr...        12   NaN    4
# 170    https://distiller.com/spirits/glen-marnoch-islay        11   NaN    1
# 176   https://distiller.com/spirits/ledaig-2005-herm...        11   NaN    3
# 194   https://distiller.com/spirits/seaweed-aeons-di...         9   NaN    2
# 201         https://distiller.com/spirits/king-s-falcon        10   NaN    2
# 205   https://distiller.com/spirits/piityvaich-12-yr...         9   NaN    5
# 222   https://distiller.com/spirits/that-boutique-y-...         8   NaN    1
# 224   https://distiller.com/spirits/spey-river-bourb...         8   NaN    2
# 231   https://distiller.com/spirits/smokehead-rock-e...         9   NaN    3
# 238   https://distiller.com/spirits/shieldaig-21-yea...         8   NaN    3
# 247   https://distiller.com/spirits/trader-joe-s-hig...         8   NaN    1
# 264   https://distiller.com/spirits/spey-river-sherr...        12   NaN    2
# 265   https://distiller.com/spirits/glen-fohdry-fion...        12   NaN    1
# 266           https://distiller.com/spirits/grangestone        14   NaN    2
# 268           https://distiller.com/spirits/dun-bheagan        14   NaN    4
# 368   https://distiller.com/spirits/port-charlotte-m...        18   NaN    4
# 390   https://distiller.com/spirits/longrow-red-13-c...        14   NaN    4
# 391    https://distiller.com/spirits/crabbie-s-yardhead        14   NaN    2
# 400   https://distiller.com/spirits/trader-joe-s-hig...        22   NaN    1
# 416           https://distiller.com/spirits/glen-fohdry        22   NaN    2
# 428   https://distiller.com/spirits/islay-gold-singl...        19   NaN    2
# 432             https://distiller.com/spirits/balnellan        20   NaN    2
# 474            https://distiller.com/spirits/spey-tenne        26   NaN    5
# 485   https://distiller.com/spirits/longrow-13-year-...        25   NaN    3
# 491   https://distiller.com/spirits/ben-bracken-high...        22   NaN    1
# 492   https://distiller.com/spirits/glen-turner-heri...        26   NaN    4
# 506   https://distiller.com/spirits/kilkerran-8-cask...        40   NaN    2
# 518   https://distiller.com/spirits/kirkland-18-year...        31   NaN    2
# 533   https://distiller.com/spirits/ben-bracken-isla...        31   NaN    1
# 542             https://distiller.com/spirits/glen-ness        29   NaN    2
# 1000  https://distiller.com/spirits/ledaig-sinclair-...         9   NaN    2
# 1002         https://distiller.com/spirits/as-we-get-it         9   NaN    3
# 1005  https://distiller.com/spirits/smokehead-extra-...        12   NaN    2
# 1017  https://distiller.com/spirits/a-d-rattray-cask...         8   NaN    3
# 1033  https://distiller.com/spirits/glengarry-single...        11   NaN    2
# 1049  https://distiller.com/spirits/ancnoc-peated-ed...         6   NaN    5
# 1104  https://distiller.com/spirits/kirkland-islay-s...        26   NaN    2
# 1183  https://distiller.com/spirits/port-charlotte-h...        12   NaN    3
# 1190  https://distiller.com/spirits/ledaig-1996-sher...        11   NaN    4
# 1234  https://distiller.com/spirits/macleod-s-islay-...        36   NaN    5
# 1315  https://distiller.com/spirits/creag-isle-singl...        50   NaN    2
#
#       Age  ...  full_bodied rich sweet  briny  salty  vanilla  tart  fruity  \
# 2      13  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 29    NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 30     12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 31     12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 32    NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 36    NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 46      6  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 58     11  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 75     18  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 79    NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 90     19  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 100    16  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 103    12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 160     8  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 168   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 169    25  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 170   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 176    11  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 194    10  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 201   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 205    12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 222    13  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 224   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 231   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 238    21  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 247   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 264   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 265   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 266   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 268   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 368   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 390    13  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 391   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 400    10  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 416   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 428    10  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 432   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 474   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 485    13  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 491   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 492   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 506     8  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 518    18  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 533   NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 542    12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1000  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1002  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1005  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1017  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1033  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1049  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1104  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1183  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1190   19  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1234  NAS  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
# 1315   12  ...          NaN  NaN   NaN    NaN    NaN      NaN   NaN     NaN
#
#       floral  Distiller
# 2        NaN        NaN
# 29       NaN        NaN
# 30       NaN        NaN
# 31       NaN        NaN
# 32       NaN        NaN
# 36       NaN        NaN
# 46       NaN        NaN
# 58       NaN        NaN
# 75       NaN        NaN
# 79       NaN        NaN
# 90       NaN        NaN
# 100      NaN        NaN
# 103      NaN        NaN
# 160      NaN        NaN
# 168      NaN        NaN
# 169      NaN        NaN
# 170      NaN        NaN
# 176      NaN        NaN
# 194      NaN        NaN
# 201      NaN        NaN
# 205      NaN        NaN
# 222      NaN        NaN
# 224      NaN        NaN
# 231      NaN        NaN
# 238      NaN        NaN
# 247      NaN        NaN
# 264      NaN        NaN
# 265      NaN        NaN
# 266      NaN        NaN
# 268      NaN        NaN
# 368      NaN        NaN
# 390      NaN        NaN
# 391      NaN        NaN
# 400      NaN        NaN
# 416      NaN        NaN
# 428      NaN        NaN
# 432      NaN        NaN
# 474      NaN        NaN
# 485      NaN        NaN
# 491      NaN        NaN
# 492      NaN        NaN
# 506      NaN        NaN
# 518      NaN        NaN
# 533      NaN        NaN
# 542      NaN        NaN
# 1000     NaN        NaN
# 1002     NaN        NaN
# 1005     NaN        NaN
# 1017     NaN        NaN
# 1033     NaN        NaN
# 1049     NaN        NaN
# 1104     NaN        NaN
# 1183     NaN        NaN
# 1190     NaN        NaN
# 1234     NaN        NaN
# 1315     NaN        NaN
#
# [56 rows x 28 columns]

# %%
# SET Missing Distilleries as OTHER for now? 
df_main_full['Distiller'] = df_main_full['Distiller'].fillna('OTHER')

# %%
# CLEAN UP Whiskey Location

df_main_full['Whisk_Loc'] = df_main_full['Whisk_Loc'].str.upper()
df_main_full['Whisk_Loc'].unique()

loc_final = [re.sub(r'[.,!?]','', str(x)) for x in df_main_full['Whisk_Loc']]
loc_final = [re.sub(r'SCOTLAND(.*)','', str(y)) for y in loc_final]
loc_final = [re.sub(r'nan','NAS', str(y)) for y in loc_final]
loc_final = [re.sub(r'I[\s]*S[\s]*L[\s]*A[\s]*Y', 'ISLAY', str(y)) for y in loc_final]
loc_final = [re.sub(r'SPEY[ESIDFR]*', 'SPEYSIDE', str(y)) for y in loc_final]
loc_final = [re.sub(r'HI[GHN]*LAN[DSFER]*', 'HIGHLAND', str(y)) for y in loc_final]
loc_final = [re.sub(r'CAM[BP]*EL[LTOWN]*', 'CAMPBELTOWN', str(y)) for y in loc_final]
loc_final = [str(y).strip() for y in loc_final]

df_main_full['Whisk_Loc'] = loc_final

# %%
# SAVE RESULTS 
df_main_full.to_csv('../Datasets/whiskeys_full_df_v2.csv', index = False)
